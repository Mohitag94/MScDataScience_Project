# %%
from keras.utils import plot_model
import visualkeras
import os

# %%
import keras

# %%
path = r"D:\MScDataScience\7.Data_Science_Project\SourceCode\Plots"
title="single"
model=keras.saving.load_model(r"D:\MScDataScience\7.Data_Science_Project\Model_Callbacks\Single_lstm\hp_96Batch_50epochs.keras")
# saving overall view of model
plot_model(model,
            to_file=os.path.join(path,
                                f"{title}_seq.png"),
            show_shapes=True,
            show_layer_names=True)
# saving layered view
visualkeras.layered_view(model,
                            legend=True,
                            to_file=os.path.\
                            join(path,
                                f"{title}_layered_view.png"), scale_z=0.01, scale_xy=4)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# <PIL.Image.Image image mode=RGBA size=170x436>

# %%
path = r"D:\MScDataScience\7.Data_Science_Project\SourceCode\Plots"
title="stacked"
model=keras.saving.load_model(r"D:\MScDataScience\7.Data_Science_Project\Model_Callbacks\Stacked_lstm\hp_176Batch_30epochs.keras")
# saving overall view of model
plot_model(model,
            to_file=os.path.join(path,
                                f"{title}_seq.png"),
            show_shapes=True,
            show_layer_names=True)
# saving layered view
visualkeras.layered_view(model,
                            legend=True,
                            to_file=os.path.\
                            join(path,
                                f"{title}_layered_view.png"), scale_z=0.001, scale_xy=3)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# <PIL.Image.Image image mode=RGBA size=197x449>

# %%
path = r"D:\MScDataScience\7.Data_Science_Project\SourceCode\Plots"
title="convo"
model=keras.saving.load_model(r"D:\MScDataScience\7.Data_Science_Project\Model_Callbacks\Convo_lstm\hp_240Batch_30epochs.keras")
# saving overall view of model
plot_model(model,
            to_file=os.path.join(path,
                                f"{title}_seq.png"),
            show_shapes=True,
            show_layer_names=True)
# saving layered view
visualkeras.layered_view(model,
                            legend=True,
                            to_file=os.path.\
                            join(path,
                                f"{title}_layered_view.png"), scale_xy=1, one_dim_orientation="z", scale_z=.001)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# <PIL.Image.Image image mode=RGBA size=227x483>
